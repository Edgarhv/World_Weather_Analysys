# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
import json
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 743

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# for i, item in enumerate(list):

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kovernino
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | rawson
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | wanning
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | ketchikan
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | arraial do cabo
# Processing Record 10 of Set 1 | fortuna
# Processing Record 11 of Set 1 | chuy
# Processing Record 12 of Set 1 | san felipe
# Processing Record 13 of Set 1 | kruisfontein
# Processing Record 14 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 1 | salinas
# Processing Record 17 of Set 1 | esperance
# Processing Record 18 of Set 1 | vostok
# Processing Record 19 of Set 1 | vondrozo
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | sabang
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | palmer
# Processing Record 26 of Set 1 | mananjary
# Processing Record 27 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 1 | necochea
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | nara
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | mount isa
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | cockburn town
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | darnah
# Processing Record 38 of Set 1 | guerrero negro
# Processing Record 39 of Set 1 | provideniya
# Processing Record 40 of Set 1 | san cristobal
# Processing Record 41 of Set 1 | kaoma
# Processing Record 42 of Set 1 | arnia
# Processing Record 43 of Set 1 | choctaw
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | aykhal
# Processing Record 46 of Set 1 | ust-kan
# Processing Record 47 of Set 1 | lompoc
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | khao yoi
# Processing Record 2 of Set 2 | wundanyi
# Processing Record 3 of Set 2 | formoso do araguaia
# City not found. Skipping...
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | chapais
# Processing Record 6 of Set 2 | toledo
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | belyy yar
# Processing Record 10 of Set 2 | west bay
# Processing Record 11 of Set 2 | vanimo
# Processing Record 12 of Set 2 | dondo
# Processing Record 13 of Set 2 | pringsewu
# Processing Record 14 of Set 2 | codrington
# Processing Record 15 of Set 2 | saldanha
# Processing Record 16 of Set 2 | kailua
# Processing Record 17 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 2 | zalantun
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | cap-chat
# Processing Record 21 of Set 2 | shibarghan
# City not found. Skipping...
# Processing Record 22 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 2 | mamit
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | smidovich
# Processing Record 26 of Set 2 | wadi
# Processing Record 27 of Set 2 | kloulklubed
# Processing Record 28 of Set 2 | zhigansk
# Processing Record 29 of Set 2 | carutapera
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | vilhena
# Processing Record 32 of Set 2 | melilla
# Processing Record 33 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 2 | aklavik
# Processing Record 35 of Set 2 | sao filipe
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | macklin
# Processing Record 39 of Set 2 | tuatapere
# Processing Record 40 of Set 2 | grindavik
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 2 | lima
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | mogadishu
# Processing Record 47 of Set 2 | davidson
# Processing Record 48 of Set 2 | yuncheng
# Processing Record 49 of Set 2 | barra da estiva
# Processing Record 50 of Set 2 | kiunga
# Processing Record 1 of Set 3 | matay
# Processing Record 2 of Set 3 | sao joao da barra
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | yingzhong
# City not found. Skipping...
# Processing Record 5 of Set 3 | daru
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | mataura
# Processing Record 10 of Set 3 | jacareacanga
# Processing Record 11 of Set 3 | samarai
# Processing Record 12 of Set 3 | port elizabeth
# Processing Record 13 of Set 3 | codajas
# Processing Record 14 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | tazovskiy
# Processing Record 17 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | ye
# City not found. Skipping...
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 3 | torres
# Processing Record 23 of Set 3 | baffa
# Processing Record 24 of Set 3 | yellowknife
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 3 | thano bula khan
# City not found. Skipping...
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | cravo norte
# Processing Record 32 of Set 3 | oranjemund
# Processing Record 33 of Set 3 | korla
# Processing Record 34 of Set 3 | mitsamiouli
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | tambura
# Processing Record 37 of Set 3 | alice springs
# Processing Record 38 of Set 3 | laukaa
# Processing Record 39 of Set 3 | sakaraha
# Processing Record 40 of Set 3 | olafsvik
# Processing Record 41 of Set 3 | chabahar
# Processing Record 42 of Set 3 | octeville
# Processing Record 43 of Set 3 | longyearbyen
# Processing Record 44 of Set 3 | shar
# Processing Record 45 of Set 3 | sur
# Processing Record 46 of Set 3 | hobart
# Processing Record 47 of Set 3 | owando
# Processing Record 48 of Set 3 | puteyets
# Processing Record 49 of Set 3 | obidos
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | bowen
# Processing Record 3 of Set 4 | pangnirtung
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | mokolo
# Processing Record 6 of Set 4 | vryburg
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | souillac
# Processing Record 9 of Set 4 | avera
# Processing Record 10 of Set 4 | russell
# Processing Record 11 of Set 4 | lebu
# Processing Record 12 of Set 4 | ontario
# Processing Record 13 of Set 4 | maturin
# Processing Record 14 of Set 4 | nichinan
# Processing Record 15 of Set 4 | narbonne
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | brae
# Processing Record 18 of Set 4 | tautira
# Processing Record 19 of Set 4 | bilibino
# Processing Record 20 of Set 4 | huoqiu
# Processing Record 21 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 4 | luorong
# Processing Record 23 of Set 4 | pak chong
# Processing Record 24 of Set 4 | kvarkeno
# Processing Record 25 of Set 4 | cururupu
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | marawi
# Processing Record 28 of Set 4 | broome
# Processing Record 29 of Set 4 | puerto escondido
# Processing Record 30 of Set 4 | college
# Processing Record 31 of Set 4 | port lincoln
# Processing Record 32 of Set 4 | kaitangata
# Processing Record 33 of Set 4 | tecoanapa
# Processing Record 34 of Set 4 | bengkulu
# Processing Record 35 of Set 4 | izmir
# Processing Record 36 of Set 4 | turukhansk
# Processing Record 37 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 4 | beloha
# Processing Record 39 of Set 4 | moindou
# Processing Record 40 of Set 4 | gizo
# Processing Record 41 of Set 4 | sambava
# Processing Record 42 of Set 4 | valparaiso
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | sorland
# Processing Record 45 of Set 4 | sibolga
# Processing Record 46 of Set 4 | lourdes
# Processing Record 47 of Set 4 | butaritari
# Processing Record 48 of Set 4 | teya
# Processing Record 49 of Set 4 | yian
# City not found. Skipping...
# Processing Record 50 of Set 4 | castro
# Processing Record 1 of Set 5 | velyka bahachka
# Processing Record 2 of Set 5 | big spring
# Processing Record 3 of Set 5 | hambantota
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | bonthe
# Processing Record 6 of Set 5 | barrow
# Processing Record 7 of Set 5 | qasigiannguit
# Processing Record 8 of Set 5 | port-gentil
# Processing Record 9 of Set 5 | mayo
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | ajdabiya
# Processing Record 12 of Set 5 | gorontalo
# Processing Record 13 of Set 5 | waddan
# Processing Record 14 of Set 5 | rio rancho
# Processing Record 15 of Set 5 | haines junction
# Processing Record 16 of Set 5 | usinsk
# Processing Record 17 of Set 5 | say
# Processing Record 18 of Set 5 | marechal candido rondon
# Processing Record 19 of Set 5 | farsund
# Processing Record 20 of Set 5 | hasaki
# Processing Record 21 of Set 5 | faanui
# Processing Record 22 of Set 5 | victoria
# Processing Record 23 of Set 5 | half moon bay
# Processing Record 24 of Set 5 | charsadda
# Processing Record 25 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 5 | bosobolo
# Processing Record 27 of Set 5 | qui nhon
# Processing Record 28 of Set 5 | buritizeiro
# Processing Record 29 of Set 5 | broken hill
# Processing Record 30 of Set 5 | berdigestyakh
# Processing Record 31 of Set 5 | tezu
# Processing Record 32 of Set 5 | coquimbo
# Processing Record 33 of Set 5 | iranshahr
# Processing Record 34 of Set 5 | dunmore town
# Processing Record 35 of Set 5 | benghazi
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | caravelas
# Processing Record 38 of Set 5 | nouakchott
# Processing Record 39 of Set 5 | poronaysk
# Processing Record 40 of Set 5 | the valley
# Processing Record 41 of Set 5 | siguiri
# Processing Record 42 of Set 5 | batagay-alyta
# Processing Record 43 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | nchelenge
# Processing Record 45 of Set 5 | te anau
# Processing Record 46 of Set 5 | chokurdakh
# Processing Record 47 of Set 5 | srednekolymsk
# Processing Record 48 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 5 | kasempa
# Processing Record 50 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 6 | pemba
# Processing Record 2 of Set 6 | dukat
# Processing Record 3 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 4 of Set 6 | isangel
# Processing Record 5 of Set 6 | kango
# Processing Record 6 of Set 6 | kaduna
# Processing Record 7 of Set 6 | vao
# Processing Record 8 of Set 6 | khatanga
# Processing Record 9 of Set 6 | fort morgan
# Processing Record 10 of Set 6 | constitucion
# Processing Record 11 of Set 6 | wattegama
# Processing Record 12 of Set 6 | asau
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | evensk
# Processing Record 15 of Set 6 | uri
# Processing Record 16 of Set 6 | leningradskiy
# Processing Record 17 of Set 6 | upington
# Processing Record 18 of Set 6 | jacqueville
# Processing Record 19 of Set 6 | margate
# Processing Record 20 of Set 6 | mnogovershinnyy
# Processing Record 21 of Set 6 | lorengau
# Processing Record 22 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 6 | viedma
# Processing Record 25 of Set 6 | nouadhibou
# Processing Record 26 of Set 6 | parsons
# Processing Record 27 of Set 6 | along
# Processing Record 28 of Set 6 | gat
# Processing Record 29 of Set 6 | puerto leguizamo
# Processing Record 30 of Set 6 | san patricio
# Processing Record 31 of Set 6 | naryan-mar
# Processing Record 32 of Set 6 | mabaruma
# Processing Record 33 of Set 6 | bayan
# Processing Record 34 of Set 6 | acapulco
# Processing Record 35 of Set 6 | tuyan
# Processing Record 36 of Set 6 | comodoro rivadavia
# Processing Record 37 of Set 6 | richards bay
# Processing Record 38 of Set 6 | sao joaquim
# Processing Record 39 of Set 6 | mahebourg
# Processing Record 40 of Set 6 | kutum
# Processing Record 41 of Set 6 | mantua
# Processing Record 42 of Set 6 | creel
# Processing Record 43 of Set 6 | chiredzi
# Processing Record 44 of Set 6 | winneba
# Processing Record 45 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 6 | mancio lima
# Processing Record 47 of Set 6 | nsanje
# Processing Record 48 of Set 6 | thompson
# Processing Record 49 of Set 6 | pozo colorado
# Processing Record 50 of Set 6 | salinopolis
# Processing Record 1 of Set 7 | morrope
# Processing Record 2 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 7 | bambous virieux
# Processing Record 4 of Set 7 | tucuman
# Processing Record 5 of Set 7 | stony brook
# Processing Record 6 of Set 7 | zima
# Processing Record 7 of Set 7 | tukan
# Processing Record 8 of Set 7 | alofi
# Processing Record 9 of Set 7 | abu dhabi
# Processing Record 10 of Set 7 | ihosy
# Processing Record 11 of Set 7 | den helder
# Processing Record 12 of Set 7 | colares
# Processing Record 13 of Set 7 | trois-rivieres
# Processing Record 14 of Set 7 | surab
# Processing Record 15 of Set 7 | dunedin
# Processing Record 16 of Set 7 | pacific grove
# Processing Record 17 of Set 7 | regina
# Processing Record 18 of Set 7 | hualmay
# Processing Record 19 of Set 7 | norilsk
# Processing Record 20 of Set 7 | vohibinany
# Processing Record 21 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 7 | fort nelson
# Processing Record 23 of Set 7 | pavelets
# Processing Record 24 of Set 7 | ust-nera
# Processing Record 25 of Set 7 | syracuse
# Processing Record 26 of Set 7 | sola
# Processing Record 27 of Set 7 | siverek
# Processing Record 28 of Set 7 | lowestoft
# Processing Record 29 of Set 7 | airai
# Processing Record 30 of Set 7 | abalak
# Processing Record 31 of Set 7 | datong
# Processing Record 32 of Set 7 | adrar
# Processing Record 33 of Set 7 | vicente guerrero
# Processing Record 34 of Set 7 | ciudad bolivar
# Processing Record 35 of Set 7 | temirtau
# Processing Record 36 of Set 7 | ornskoldsvik
# Processing Record 37 of Set 7 | novoilinsk
# Processing Record 38 of Set 7 | nioro
# Processing Record 39 of Set 7 | zhigalovo
# Processing Record 40 of Set 7 | beyneu
# Processing Record 41 of Set 7 | fuerte olimpo
# Processing Record 42 of Set 7 | kodinar
# Processing Record 43 of Set 7 | norman wells
# Processing Record 44 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 45 of Set 7 | bac can
# City not found. Skipping...
# Processing Record 46 of Set 7 | grand-santi
# Processing Record 47 of Set 7 | arzakan
# Processing Record 48 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 7 | kawalu
# Processing Record 50 of Set 7 | eyl
# Processing Record 1 of Set 8 | mulanje
# Processing Record 2 of Set 8 | okakarara
# Processing Record 3 of Set 8 | honningsvag
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | havre-saint-pierre
# Processing Record 6 of Set 8 | quatre cocos
# Processing Record 7 of Set 8 | vila
# Processing Record 8 of Set 8 | kavaratti
# Processing Record 9 of Set 8 | maridi
# Processing Record 10 of Set 8 | karratha
# Processing Record 11 of Set 8 | nushki
# Processing Record 12 of Set 8 | cidreira
# Processing Record 13 of Set 8 | chau doc
# Processing Record 14 of Set 8 | yerbogachen
# Processing Record 15 of Set 8 | vila velha
# Processing Record 16 of Set 8 | port keats
# Processing Record 17 of Set 8 | nemuro
# Processing Record 18 of Set 8 | kirensk
# Processing Record 19 of Set 8 | bac lieu
# Processing Record 20 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 8 | mangrol
# Processing Record 22 of Set 8 | port macquarie
# Processing Record 23 of Set 8 | nipawin
# Processing Record 24 of Set 8 | namibe
# Processing Record 25 of Set 8 | oriximina
# Processing Record 26 of Set 8 | zyryanka
# Processing Record 27 of Set 8 | camuy
# Processing Record 28 of Set 8 | mount gambier
# Processing Record 29 of Set 8 | chicama
# Processing Record 30 of Set 8 | shingu
# Processing Record 31 of Set 8 | taksimo
# Processing Record 32 of Set 8 | manta
# Processing Record 33 of Set 8 | balkhash
# Processing Record 34 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 8 | huinan
# Processing Record 36 of Set 8 | atambua
# Processing Record 37 of Set 8 | ballina
# Processing Record 38 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 8 | igaci
# Processing Record 40 of Set 8 | kiama
# Processing Record 41 of Set 8 | tynda
# Processing Record 42 of Set 8 | novikovo
# Processing Record 43 of Set 8 | saskylakh
# Processing Record 44 of Set 8 | klaksvik
# Processing Record 45 of Set 8 | mason city
# Processing Record 46 of Set 8 | tortoli
# Processing Record 47 of Set 8 | itarema
# Processing Record 48 of Set 8 | sobolevo
# Processing Record 49 of Set 8 | tasiilaq
# Processing Record 50 of Set 8 | evanston
# Processing Record 1 of Set 9 | husavik
# Processing Record 2 of Set 9 | shakhunya
# Processing Record 3 of Set 9 | rocha
# Processing Record 4 of Set 9 | coolum beach
# Processing Record 5 of Set 9 | changde
# Processing Record 6 of Set 9 | aksarka
# Processing Record 7 of Set 9 | ca mau
# Processing Record 8 of Set 9 | assiniboia
# Processing Record 9 of Set 9 | port augusta
# Processing Record 10 of Set 9 | kodiak
# Processing Record 11 of Set 9 | sisimiut
# Processing Record 12 of Set 9 | bakel
# Processing Record 13 of Set 9 | padang
# Processing Record 14 of Set 9 | ucluelet
# Processing Record 15 of Set 9 | rantoul
# Processing Record 16 of Set 9 | taoudenni
# Processing Record 17 of Set 9 | pemangkat
# Processing Record 18 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 9 | deer lake
# Processing Record 20 of Set 9 | sunel
# Processing Record 21 of Set 9 | escarcega
# Processing Record 22 of Set 9 | a
# City not found. Skipping...
# Processing Record 23 of Set 9 | poya
# Processing Record 24 of Set 9 | lata
# Processing Record 25 of Set 9 | terra santa
# Processing Record 26 of Set 9 | camacha
# Processing Record 27 of Set 9 | biltine
# Processing Record 28 of Set 9 | narsaq
# Processing Record 29 of Set 9 | najran
# Processing Record 30 of Set 9 | liwale
# Processing Record 31 of Set 9 | nanortalik
# Processing Record 32 of Set 9 | portland
# Processing Record 33 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 34 of Set 9 | simi
# Processing Record 35 of Set 9 | batyrevo
# Processing Record 36 of Set 9 | okotoks
# Processing Record 37 of Set 9 | ternate
# Processing Record 38 of Set 9 | fairbanks
# Processing Record 39 of Set 9 | thongwa
# Processing Record 40 of Set 9 | menongue
# Processing Record 41 of Set 9 | tukrah
# Processing Record 42 of Set 9 | mbini
# Processing Record 43 of Set 9 | pangian
# Processing Record 44 of Set 9 | port hardy
# Processing Record 45 of Set 9 | mikhaylovka
# Processing Record 46 of Set 9 | san vicente de canete
# Processing Record 47 of Set 9 | lagoa
# Processing Record 48 of Set 9 | grand gaube
# Processing Record 49 of Set 9 | el carrizo
# Processing Record 50 of Set 9 | twin falls
# Processing Record 1 of Set 10 | erzin
# Processing Record 2 of Set 10 | mariager
# Processing Record 3 of Set 10 | katsina
# Processing Record 4 of Set 10 | komsomolskiy
# Processing Record 5 of Set 10 | verkh-usugli
# Processing Record 6 of Set 10 | san francisco
# Processing Record 7 of Set 10 | roma
# Processing Record 8 of Set 10 | ilhabela
# Processing Record 9 of Set 10 | port shepstone
# Processing Record 10 of Set 10 | beira
# Processing Record 11 of Set 10 | alenquer
# Processing Record 12 of Set 10 | filingue
# Processing Record 13 of Set 10 | pampierstad
# Processing Record 14 of Set 10 | dubrovnik
# Processing Record 15 of Set 10 | honiara
# Processing Record 16 of Set 10 | maymyo
# Processing Record 17 of Set 10 | wad madani
# Processing Record 18 of Set 10 | dossor
# Processing Record 19 of Set 10 | beringovskiy
# Processing Record 20 of Set 10 | creston
# Processing Record 21 of Set 10 | kapoeta
# Processing Record 22 of Set 10 | bandarbeyla
# Processing Record 23 of Set 10 | kalanguy
# Processing Record 24 of Set 10 | victor harbor
# Processing Record 25 of Set 10 | novo aripuana
# Processing Record 26 of Set 10 | lavrentiya
# Processing Record 27 of Set 10 | jhalawar
# Processing Record 28 of Set 10 | champerico
# Processing Record 29 of Set 10 | salalah
# Processing Record 30 of Set 10 | polis
# Processing Record 31 of Set 10 | tilichiki
# Processing Record 32 of Set 10 | alyangula
# Processing Record 33 of Set 10 | illapel
# Processing Record 34 of Set 10 | ila
# Processing Record 35 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 10 | belmonte
# Processing Record 38 of Set 10 | porgera
# Processing Record 39 of Set 10 | montecristo
# Processing Record 40 of Set 10 | maneadero
# Processing Record 41 of Set 10 | campbell river
# Processing Record 42 of Set 10 | severo-kurilsk
# Processing Record 43 of Set 10 | edd
# Processing Record 44 of Set 10 | torbay
# Processing Record 45 of Set 10 | tolaga bay
# Processing Record 46 of Set 10 | sao raimundo das mangabeiras
# Processing Record 47 of Set 10 | touros
# Processing Record 48 of Set 10 | matara
# Processing Record 49 of Set 10 | berlevag
# Processing Record 50 of Set 10 | nam som
# Processing Record 1 of Set 11 | rudbar
# Processing Record 2 of Set 11 | buraydah
# Processing Record 3 of Set 11 | waterloo
# Processing Record 4 of Set 11 | nadym
# Processing Record 5 of Set 11 | omsukchan
# Processing Record 6 of Set 11 | shcholkine
# City not found. Skipping...
# Processing Record 7 of Set 11 | vila franca do campo
# Processing Record 8 of Set 11 | ljungby
# Processing Record 9 of Set 11 | lismore
# Processing Record 10 of Set 11 | erenhot
# Processing Record 11 of Set 11 | muscat
# Processing Record 12 of Set 11 | kahului
# Processing Record 13 of Set 11 | xining
# Processing Record 14 of Set 11 | harwich
# Processing Record 15 of Set 11 | klang
# Processing Record 16 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 11 | brigantine
# Processing Record 18 of Set 11 | cayenne
# Processing Record 19 of Set 11 | madison
# Processing Record 20 of Set 11 | ambo
# Processing Record 21 of Set 11 | namatanai
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | abu samrah
# Processing Record 24 of Set 11 | lagos
# Processing Record 25 of Set 11 | osa
# Processing Record 26 of Set 11 | puerto madryn
# Processing Record 27 of Set 11 | khuzhir
# Processing Record 28 of Set 11 | porto belo
# Processing Record 29 of Set 11 | cheney
# Processing Record 30 of Set 11 | dudinka
# Processing Record 31 of Set 11 | samandag
# Processing Record 32 of Set 11 | hornepayne
# Processing Record 33 of Set 11 | khon buri
# Processing Record 34 of Set 11 | westport
# Processing Record 35 of Set 11 | quimper
# Processing Record 36 of Set 11 | minas novas
# Processing Record 37 of Set 11 | san quintin
# Processing Record 38 of Set 11 | inirida
# Processing Record 39 of Set 11 | zakharovo
# Processing Record 40 of Set 11 | northam
# Processing Record 41 of Set 11 | plettenberg bay
# Processing Record 42 of Set 11 | salani
# Processing Record 43 of Set 11 | anadyr
# Processing Record 44 of Set 11 | naze
# Processing Record 45 of Set 11 | davila
# Processing Record 46 of Set 11 | verkhnevilyuysk
# Processing Record 47 of Set 11 | kem
# Processing Record 48 of Set 11 | mezen
# Processing Record 49 of Set 11 | hastings
# Processing Record 50 of Set 11 | muros
# Processing Record 1 of Set 12 | auki
# Processing Record 2 of Set 12 | tessalit
# Processing Record 3 of Set 12 | yermekeyevo
# Processing Record 4 of Set 12 | kavieng
# Processing Record 5 of Set 12 | praia da vitoria
# Processing Record 6 of Set 12 | tulle
# Processing Record 7 of Set 12 | inhambane
# Processing Record 8 of Set 12 | labuhan
# Processing Record 9 of Set 12 | kholm
# Processing Record 10 of Set 12 | zhanaozen
# Processing Record 11 of Set 12 | soc trang
# Processing Record 12 of Set 12 | ambilobe
# Processing Record 13 of Set 12 | urengoy
# Processing Record 14 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 12 | pauini
# Processing Record 16 of Set 12 | banda aceh
# Processing Record 17 of Set 12 | carballo
# Processing Record 18 of Set 12 | shubarshi
# Processing Record 19 of Set 12 | craig
# Processing Record 20 of Set 12 | jinchang
# Processing Record 21 of Set 12 | marquette
# Processing Record 22 of Set 12 | sungairaya
# Processing Record 23 of Set 12 | hof
# Processing Record 24 of Set 12 | bilma
# Processing Record 25 of Set 12 | kudat
# Processing Record 26 of Set 12 | eregli
# Processing Record 27 of Set 12 | nicoya
# Processing Record 28 of Set 12 | dongsheng
# Processing Record 29 of Set 12 | tashtagol
# Processing Record 30 of Set 12 | deputatskiy
# Processing Record 31 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 12 | batemans bay
# Processing Record 33 of Set 12 | uglovskoye
# Processing Record 34 of Set 12 | staraya poltavka
# Processing Record 35 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 12 | cagliari
# Processing Record 37 of Set 12 | algiers
# Processing Record 38 of Set 12 | atherton
# Processing Record 39 of Set 12 | olutanga
# Processing Record 40 of Set 12 | zhangye
# Processing Record 41 of Set 12 | noyabrsk
# Processing Record 42 of Set 12 | leshukonskoye
# Processing Record 43 of Set 12 | ulladulla
# Processing Record 44 of Set 12 | rosarito
# Processing Record 45 of Set 12 | anaconda
# Processing Record 46 of Set 12 | tunduma
# Processing Record 47 of Set 12 | paka
# Processing Record 48 of Set 12 | vendome
# Processing Record 49 of Set 12 | esil
# Processing Record 50 of Set 12 | talnakh
# Processing Record 1 of Set 13 | roblin
# Processing Record 2 of Set 13 | guozhen
# Processing Record 3 of Set 13 | caramay
# Processing Record 4 of Set 13 | halifax
# Processing Record 5 of Set 13 | santa maria
# Processing Record 6 of Set 13 | xiongzhou
# Processing Record 7 of Set 13 | kualakapuas
# Processing Record 8 of Set 13 | emerald
# Processing Record 9 of Set 13 | faya
# Processing Record 10 of Set 13 | santa maria del rio
# Processing Record 11 of Set 13 | krasnoselkup
# Processing Record 12 of Set 13 | kemijarvi
# Processing Record 13 of Set 13 | toccoa
# Processing Record 14 of Set 13 | raudeberg
# Processing Record 15 of Set 13 | dali
# Processing Record 16 of Set 13 | ripky
# Processing Record 17 of Set 13 | megion
# Processing Record 18 of Set 13 | hovd
# Processing Record 19 of Set 13 | vizinga
# Processing Record 20 of Set 13 | gao
# Processing Record 21 of Set 13 | san ramon
# Processing Record 22 of Set 13 | paamiut
# Processing Record 23 of Set 13 | balaipungut
# Processing Record 24 of Set 13 | waipawa
# Processing Record 25 of Set 13 | bundoran
# Processing Record 26 of Set 13 | bonavista
# Processing Record 27 of Set 13 | canon city
# Processing Record 28 of Set 13 | mortka
# Processing Record 29 of Set 13 | jimma
# Processing Record 30 of Set 13 | aasiaat
# Processing Record 31 of Set 13 | peleduy
# Processing Record 32 of Set 13 | cascais
# Processing Record 33 of Set 13 | tarancon
# Processing Record 34 of Set 13 | la rioja
# Processing Record 35 of Set 13 | vestmannaeyjar
# Processing Record 36 of Set 13 | baker city
# Processing Record 37 of Set 13 | homer
# Processing Record 38 of Set 13 | rairangpur
# Processing Record 39 of Set 13 | nome
# Processing Record 40 of Set 13 | jatai
# Processing Record 41 of Set 13 | vallenar
# Processing Record 42 of Set 13 | maltahohe
# Processing Record 43 of Set 13 | baykit
# Processing Record 44 of Set 13 | loding
# Processing Record 45 of Set 13 | mayumba
# Processing Record 46 of Set 13 | igarka
# Processing Record 47 of Set 13 | roebourne
# Processing Record 48 of Set 13 | zhetybay
# City not found. Skipping...
# Processing Record 49 of Set 13 | koumac
# Processing Record 50 of Set 13 | antalaha
# Processing Record 1 of Set 14 | tocopilla
# Processing Record 2 of Set 14 | port-de-bouc
# Processing Record 3 of Set 14 | sovetskiy
# Processing Record 4 of Set 14 | one hundred mile house
# City not found. Skipping...
# Processing Record 5 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 6 of Set 14 | pitelino
# Processing Record 7 of Set 14 | pierre
# Processing Record 8 of Set 14 | thunder bay
# Processing Record 9 of Set 14 | chemal
# Processing Record 10 of Set 14 | sangar
# Processing Record 11 of Set 14 | martapura
# Processing Record 12 of Set 14 | funadhoo
# Processing Record 13 of Set 14 | putnok
# Processing Record 14 of Set 14 | tyukhtet
# Processing Record 15 of Set 14 | manado
# Processing Record 16 of Set 14 | mangai
# Processing Record 17 of Set 14 | rabo de peixe
# Processing Record 18 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 19 of Set 14 | oranmore
# Processing Record 20 of Set 14 | san carlos de bariloche
# Processing Record 21 of Set 14 | anloga
# Processing Record 22 of Set 14 | mizpe ramon
# City not found. Skipping...
# Processing Record 23 of Set 14 | aksu
# Processing Record 24 of Set 14 | shizunai
# Processing Record 25 of Set 14 | wilmington
# Processing Record 26 of Set 14 | takaka
# Processing Record 27 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 14 | svobodnyy
# Processing Record 29 of Set 14 | sakakah
# Processing Record 30 of Set 14 | bari
# Processing Record 31 of Set 14 | santa cruz
# Processing Record 32 of Set 14 | hokitika
# Processing Record 33 of Set 14 | la asuncion
# Processing Record 34 of Set 14 | keti bandar
# Processing Record 35 of Set 14 | gravdal
# Processing Record 36 of Set 14 | laharpur
# Processing Record 37 of Set 14 | hvide sande
# Processing Record 38 of Set 14 | port-cartier
# Processing Record 39 of Set 14 | ozinki
# Processing Record 40 of Set 14 | kisangani
# Processing Record 41 of Set 14 | ardabil
# Processing Record 42 of Set 14 | reyes
# Processing Record 43 of Set 14 | la ronge
# Processing Record 44 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 14 | kirakira
# Processing Record 46 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 14 | luganville
# Processing Record 48 of Set 14 | sutton
# Processing Record 49 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 50 of Set 14 | chimbote
# Processing Record 1 of Set 15 | serebryansk
# Processing Record 2 of Set 15 | kahta
# Processing Record 3 of Set 15 | mattru
# Processing Record 4 of Set 15 | karhal
# Processing Record 5 of Set 15 | ribeira brava
# Processing Record 6 of Set 15 | guapiles
# Processing Record 7 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 15 | lesnoye
# Processing Record 9 of Set 15 | amuntai
# Processing Record 10 of Set 15 | lillehammer
# Processing Record 11 of Set 15 | xuddur
# Processing Record 12 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 14 of Set 15 | sapouy
# Processing Record 15 of Set 15 | mildura
# Processing Record 16 of Set 15 | qaqortoq
# Processing Record 17 of Set 15 | havoysund
# Processing Record 18 of Set 15 | marrakesh
# Processing Record 19 of Set 15 | wapakoneta
# Processing Record 20 of Set 15 | kainantu
# Processing Record 21 of Set 15 | saint-joseph
# Processing Record 22 of Set 15 | siteki
# Processing Record 23 of Set 15 | dasoguz
# Processing Record 24 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 25 of Set 15 | pangody
# Processing Record 26 of Set 15 | yola
# Processing Record 27 of Set 15 | pulivendla
# Processing Record 28 of Set 15 | walvis bay
# Processing Record 29 of Set 15 | maloy
# Processing Record 30 of Set 15 | mushie
# Processing Record 31 of Set 15 | marzuq
# Processing Record 32 of Set 15 | hami
# Processing Record 33 of Set 15 | tabou
# Processing Record 34 of Set 15 | yichang
# Processing Record 35 of Set 15 | cedar city
# Processing Record 36 of Set 15 | movileni
# Processing Record 37 of Set 15 | sao felix do xingu
# Processing Record 38 of Set 15 | rio gallegos
# Processing Record 39 of Set 15 | terrace
# Processing Record 40 of Set 15 | changli
# Processing Record 41 of Set 15 | biak
# Processing Record 42 of Set 15 | damara
# Processing Record 43 of Set 15 | tabialan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kovernino      RU  57.1253   43.8142     70.12        62          98
# 1          Rikitea      PF -23.1203 -134.9692     69.12        61         100
# 2           Rawson      AR -43.3002  -65.1023     64.02        27          12
# 3          Ushuaia      AR -54.8000  -68.3000     44.26        70          75
# 4          Wanning      CN  18.8003  110.3967     80.91        88         100
# 5           Dikson      RU  73.5069   80.5464     39.69        98         100
# 6        Ketchikan      US  55.3422 -131.6461     61.27        82          90
# 7        Busselton      AU -33.6500  115.3333     44.10        75          77
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     75.16        64          20
# 9          Fortuna      US  40.5982 -124.1573     63.52        88           1
#
#    Wind Speed Current description
# 0        4.59          light rain
# 1       23.87     overcast clouds
# 2       11.74          few clouds
# 3        6.91       broken clouds
# 4        6.89     overcast clouds
# 5        5.82     overcast clouds
# 6        6.91     overcast clouds
# 7        7.99       broken clouds
# 8       12.66          few clouds
# 9        5.75           clear sky

# %%
# new_column_order = ["column2", "column4", "column1"]
new_order= ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current description"]
city_data_df = city_data_df[new_order] 
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kovernino      RU  57.1253   43.8142     70.12        62          98
# 1          Rikitea      PF -23.1203 -134.9692     69.12        61         100
# 2           Rawson      AR -43.3002  -65.1023     64.02        27          12
# 3          Ushuaia      AR -54.8000  -68.3000     44.26        70          75
# 4          Wanning      CN  18.8003  110.3967     80.91        88         100
# 5           Dikson      RU  73.5069   80.5464     39.69        98         100
# 6        Ketchikan      US  55.3422 -131.6461     61.27        82          90
# 7        Busselton      AU -33.6500  115.3333     44.10        75          77
# 8  Arraial Do Cabo      BR -22.9661  -42.0278     75.16        64          20
# 9          Fortuna      US  40.5982 -124.1573     63.52        88           1
#
#    Wind Speed Current description
# 0        4.59          light rain
# 1       23.87     overcast clouds
# 2       11.74          few clouds
# 3        6.91       broken clouds
# 4        6.89     overcast clouds
# 5        5.82     overcast clouds
# 6        6.91     overcast clouds
# 7        7.99       broken clouds
# 8       12.66          few clouds
# 9        5.75           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
